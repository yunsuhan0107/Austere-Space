# %%
from tensorflow.keras import backend as K
def recall(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Negative) = 실제 값이 1(Positive) 전체
    count_true_positive_false_negative = K.sum(y_target_yn)

    # Recall =  (True Positive) / (True Positive + False Negative)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    recall = count_true_positive / (count_true_positive_false_negative + K.epsilon())

    # return a single tensor value
    return recall


def precision(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Positive) = 예측 값이 1(Positive) 전체
    count_true_positive_false_positive = K.sum(y_pred_yn)

    # Precision = (True Positive) / (True Positive + False Positive)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    precision = count_true_positive / (count_true_positive_false_positive + K.epsilon())

    # return a single tensor value
    return precision


def f1score(y_target, y_pred):
    _recall = recall(y_target, y_pred)
    _precision = precision(y_target, y_pred)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    _f1score = ( 2 * _recall * _precision) / (_recall + _precision+ K.epsilon())
    
    # return a single tensor value
    return _f1score

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping
from matplotlib import pyplot as plt

# %%
# 1. 데이터 생성하기
train_datagen = ImageDataGenerator(rescale=1./255, 
                                   rotation_range=10,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.7,
                                   zoom_range=[0.9, 2.2],
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(
        'data/train',
        target_size=(32, 32),
        batch_size=3,
        class_mode='binary') 

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        'data/test',
        target_size=(32, 32),     
        batch_size=3,
        class_mode='binary')
# Out:
# Found 974 images belonging to 2 classes.
# Found 239 images belonging to 2 classes.

# %%
# 2. 모델 구성하기
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='elu', input_shape=(32,32, 3)))
model.add(Conv2D(32, (3, 3), activation='elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), activation='elu'))
model.add(Conv2D(64, (3, 3), activation='elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='elu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid')) 


# 3. 모델 학습과정 설정하기
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001)
#                  ,loss=tf.keras.losses.binary_crossentropy
#                  ,metrics=[tf.keras.metrics.Precision(name='precision')\
#                           ,tf.keras.metrics.Recall(name='recall')\
#                           ,tf.keras.metrics.FalsePositives(name='false_positives')\
#                           ,tf.keras.metrics.FalseNegatives(name='false_negatives')])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', precision, recall, f1score])

early_stopping = EarlyStopping(patience=10) # 조기종료 콜백함수 정의

# 4. 모델 학습시키기
hist = model.fit_generator(
        train_generator,
        steps_per_epoch=50, 
        epochs=50,  
        validation_data=test_generator,
        validation_steps=5,
        callbacks=[early_stopping]
        ) 

_loss, _acc, _precision, _recall, _f1score = model.evaluate_generator(test_generator, steps=5)
print('loss: {:.3f}, accuracy: {:.3f}, precision: {:.3f}, recall: {:.3f}, f1score: {:.3f}'.format(_loss, _acc, _precision, _recall, _f1score))


# # 5. 모델 평가하기
# print("-- Evaluate --")
# scores = model.evaluate_generator(test_generator, steps=5)
# print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# # 6. 모델 사용하기
# print("-- Predict --")
# output = model.predict_generator(test_generator, steps=5)
# np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
# print(test_generator.class_indices)
# print(output)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.8752 - accuracy: 0.5000 - precision: 0.2267 - recall: 0.3667 - f1score: 0.2627 - val_loss: 0.7572 - val_accuracy: 0.3333 - val_precision: 0.3333 - val_recall: 0.6000 - val_f1score: 0.4000
# Epoch 2/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.7365 - accuracy: 0.5933 - precision: 0.3600 - recall: 0.4100 - f1score: 0.3513 - val_loss: 0.9052 - val_accuracy: 0.3333 - val_precision: 0.3333 - val_recall: 0.6000 - val_f1score: 0.4000
# Epoch 3/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.7354 - accuracy: 0.5200 - precision: 0.2233 - recall: 0.2367 - f1score: 0.2173 - val_loss: 0.7669 - val_accuracy: 0.4000 - val_precision: 0.3333 - val_recall: 0.6000 - val_f1score: 0.4000
# Epoch 4/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.7339 - accuracy: 0.5067 - precision: 0.3700 - recall: 0.4467 - f1score: 0.3740 - val_loss: 0.6103 - val_accuracy: 0.6667 - val_precision: 0.3000 - val_recall: 0.3333 - val_f1score: 0.2933
# Epoch 5/50
# 50/50 [==============================] - 3s 54ms/step - loss: 0.6910 - accuracy: 0.5772 - precision: 0.4633 - recall: 0.5000 - f1score: 0.4400 - val_loss: 0.5599 - val_accuracy: 0.6667 - val_precision: 0.2000 - val_recall: 0.0667 - val_f1score: 0.1000
# Epoch 6/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.6595 - accuracy: 0.6400 - precision: 0.2600 - recall: 0.3133 - f1score: 0.2747 - val_loss: 0.5655 - val_accuracy: 0.7333 - val_precision: 0.2000 - val_recall: 0.2000 - val_f1score: 0.2000
# Epoch 7/50
# 50/50 [==============================] - 2s 46ms/step - loss: 0.7659 - accuracy: 0.5600 - precision: 0.3300 - recall: 0.3400 - f1score: 0.3027 - val_loss: 0.6129 - val_accuracy: 0.6667 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1score: 0.0000e+00
# Epoch 8/50
# 50/50 [==============================] - 2s 47ms/step - loss: 0.6802 - accuracy: 0.6644 - precision: 0.3800 - recall: 0.3700 - f1score: 0.3520 - val_loss: 0.6086 - val_accuracy: 0.6667 - val_precision: 0.4000 - val_recall: 0.2667 - val_f1score: 0.3000
# Epoch 9/50
# 50/50 [==============================] - 2s 43ms/step - loss: 0.5301 - accuracy: 0.7467 - precision: 0.5767 - recall: 0.5833 - f1score: 0.5447 - val_loss: 0.7888 - val_accuracy: 0.7333 - val_precision: 0.4000 - val_recall: 0.6000 - val_f1score: 0.4667
# Epoch 10/50
# 50/50 [==============================] - 2s 42ms/step - loss: 0.6674 - accuracy: 0.6400 - precision: 0.3200 - recall: 0.3200 - f1score: 0.3000 - val_loss: 0.5885 - val_accuracy: 0.7333 - val_precision: 0.2000 - val_recall: 0.0667 - val_f1score: 0.1000
# Epoch 11/50
# 50/50 [==============================] - 2s 41ms/step - loss: 0.6607 - accuracy: 0.6200 - precision: 0.3933 - recall: 0.3800 - f1score: 0.3660 - val_loss: 0.6521 - val_accuracy: 0.6000 - val_precision: 0.4667 - val_recall: 0.6000 - val_f1score: 0.5000
# Epoch 12/50
# 50/50 [==============================] - 2s 45ms/step - loss: 0.5304 - accuracy: 0.7467 - precision: 0.6833 - recall: 0.6933 - f1score: 0.6607 - val_loss: 0.5270 - val_accuracy: 0.6667 - val_precision: 0.4000 - val_recall: 0.4667 - val_f1score: 0.3667
# Epoch 13/50
# 50/50 [==============================] - 2s 42ms/step - loss: 0.6047 - accuracy: 0.6733 - precision: 0.4800 - recall: 0.5000 - f1score: 0.4533 - val_loss: 0.4962 - val_accuracy: 0.8000 - val_precision: 0.4000 - val_recall: 0.2667 - val_f1score: 0.3000
# Epoch 14/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.6254 - accuracy: 0.6133 - precision: 0.5267 - recall: 0.5467 - f1score: 0.4947 - val_loss: 0.4818 - val_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.5333 - val_f1score: 0.4933
# Epoch 15/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.5261 - accuracy: 0.7333 - precision: 0.5367 - recall: 0.5800 - f1score: 0.5253 - val_loss: 0.4784 - val_accuracy: 0.7333 - val_precision: 0.4667 - val_recall: 0.6000 - val_f1score: 0.5000
# Epoch 16/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.4796 - accuracy: 0.7667 - precision: 0.5900 - recall: 0.5733 - f1score: 0.5540 - val_loss: 0.6135 - val_accuracy: 0.6000 - val_precision: 0.3667 - val_recall: 0.6000 - val_f1score: 0.4333
# Epoch 17/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.5589 - accuracy: 0.7067 - precision: 0.5067 - recall: 0.6000 - f1score: 0.5207 - val_loss: 0.6790 - val_accuracy: 0.6667 - val_precision: 0.3667 - val_recall: 0.6000 - val_f1score: 0.4333
# Epoch 18/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.6144 - accuracy: 0.6667 - precision: 0.5633 - recall: 0.5167 - f1score: 0.5067 - val_loss: 0.7573 - val_accuracy: 0.6667 - val_precision: 0.3667 - val_recall: 0.6000 - val_f1score: 0.4333
# Epoch 19/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.5678 - accuracy: 0.7267 - precision: 0.5133 - recall: 0.5300 - f1score: 0.4980 - val_loss: 0.5151 - val_accuracy: 0.6000 - val_precision: 0.3667 - val_recall: 0.5333 - val_f1score: 0.3933
# Epoch 20/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.5455 - accuracy: 0.7315 - precision: 0.4833 - recall: 0.5000 - f1score: 0.4807 - val_loss: 0.4910 - val_accuracy: 0.7333 - val_precision: 0.3667 - val_recall: 0.6000 - val_f1score: 0.4333
# Epoch 21/50
# 50/50 [==============================] - 2s 42ms/step - loss: 0.5132 - accuracy: 0.7517 - precision: 0.5600 - recall: 0.4867 - f1score: 0.5053 - val_loss: 0.4627 - val_accuracy: 0.6000 - val_precision: 0.4667 - val_recall: 0.5333 - val_f1score: 0.4600
# Epoch 22/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.4322 - accuracy: 0.8000 - precision: 0.6400 - recall: 0.6600 - f1score: 0.6240 - val_loss: 0.2948 - val_accuracy: 0.8667 - val_precision: 0.4000 - val_recall: 0.3333 - val_f1score: 0.3600
# Epoch 23/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.4763 - accuracy: 0.7533 - precision: 0.4200 - recall: 0.4500 - f1score: 0.4147 - val_loss: 0.4423 - val_accuracy: 0.7333 - val_precision: 0.3667 - val_recall: 0.6000 - val_f1score: 0.4333
# Epoch 24/50
# 50/50 [==============================] - 2s 41ms/step - loss: 0.4393 - accuracy: 0.8000 - precision: 0.6833 - recall: 0.6967 - f1score: 0.6687 - val_loss: 0.3866 - val_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.5333 - val_f1score: 0.4933
# Epoch 25/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.4712 - accuracy: 0.7467 - precision: 0.5967 - recall: 0.5533 - f1score: 0.5433 - val_loss: 0.4959 - val_accuracy: 0.7333 - val_precision: 0.5000 - val_recall: 0.6000 - val_f1score: 0.5333
# Epoch 26/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.5635 - accuracy: 0.7200 - precision: 0.6333 - recall: 0.5967 - f1score: 0.5887 - val_loss: 0.3450 - val_accuracy: 1.0000 - val_precision: 0.6000 - val_recall: 0.6000 - val_f1score: 0.6000
# Epoch 27/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.4572 - accuracy: 0.7933 - precision: 0.6433 - recall: 0.6467 - f1score: 0.6193 - val_loss: 0.4983 - val_accuracy: 0.6667 - val_precision: 0.3667 - val_recall: 0.6000 - val_f1score: 0.4333
# Epoch 28/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.5503 - accuracy: 0.7800 - precision: 0.5233 - recall: 0.5300 - f1score: 0.5193 - val_loss: 0.4409 - val_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.5333 - val_f1score: 0.4933
# Epoch 29/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.4392 - accuracy: 0.7933 - precision: 0.7533 - recall: 0.7700 - f1score: 0.7360 - val_loss: 0.5110 - val_accuracy: 0.7333 - val_precision: 0.5000 - val_recall: 0.5333 - val_f1score: 0.4933
# Epoch 30/50
# 50/50 [==============================] - 2s 41ms/step - loss: 0.4083 - accuracy: 0.8000 - precision: 0.5933 - recall: 0.5567 - f1score: 0.5593 - val_loss: 0.5423 - val_accuracy: 0.6667 - val_precision: 0.4000 - val_recall: 0.6000 - val_f1score: 0.4667
# Epoch 31/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.4559 - accuracy: 0.7852 - precision: 0.6367 - recall: 0.6300 - f1score: 0.6040 - val_loss: 0.3440 - val_accuracy: 0.8000 - val_precision: 0.4000 - val_recall: 0.6000 - val_f1score: 0.4667
# Epoch 32/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.4104 - accuracy: 0.8533 - precision: 0.7067 - recall: 0.6633 - f1score: 0.6613 - val_loss: 0.1925 - val_accuracy: 1.0000 - val_precision: 0.6000 - val_recall: 0.6000 - val_f1score: 0.6000
# Epoch 33/50
# 50/50 [==============================] - 2s 41ms/step - loss: 0.4562 - accuracy: 0.7933 - precision: 0.6200 - recall: 0.7000 - f1score: 0.6347 - val_loss: 0.2740 - val_accuracy: 0.8667 - val_precision: 0.5000 - val_recall: 0.5333 - val_f1score: 0.4933
# Epoch 34/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.4868 - accuracy: 0.7733 - precision: 0.6133 - recall: 0.6033 - f1score: 0.5767 - val_loss: 0.2461 - val_accuracy: 0.9333 - val_precision: 0.6000 - val_recall: 0.5333 - val_f1score: 0.5600
# Epoch 35/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.4745 - accuracy: 0.7733 - precision: 0.5967 - recall: 0.6333 - f1score: 0.5907 - val_loss: 0.2536 - val_accuracy: 0.9333 - val_precision: 0.6000 - val_recall: 0.5333 - val_f1score: 0.5600
# Epoch 36/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.4435 - accuracy: 0.7733 - precision: 0.6133 - recall: 0.6767 - f1score: 0.6240 - val_loss: 0.3662 - val_accuracy: 0.8667 - val_precision: 0.4000 - val_recall: 0.6000 - val_f1score: 0.4667
# Epoch 37/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.4400 - accuracy: 0.7987 - precision: 0.6767 - recall: 0.6900 - f1score: 0.6547 - val_loss: 0.2439 - val_accuracy: 0.8667 - val_precision: 0.5000 - val_recall: 0.5333 - val_f1score: 0.4933
# Epoch 38/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.4147 - accuracy: 0.8400 - precision: 0.6367 - recall: 0.6100 - f1score: 0.6053 - val_loss: 0.3746 - val_accuracy: 0.8667 - val_precision: 0.5000 - val_recall: 0.6000 - val_f1score: 0.5333
# Epoch 39/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.4560 - accuracy: 0.8000 - precision: 0.7433 - recall: 0.7700 - f1score: 0.7300 - val_loss: 0.4356 - val_accuracy: 0.8000 - val_precision: 0.4000 - val_recall: 0.6000 - val_f1score: 0.4667
# Epoch 40/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.5001 - accuracy: 0.7919 - precision: 0.6167 - recall: 0.6333 - f1score: 0.6013 - val_loss: 0.3445 - val_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.6000 - val_f1score: 0.5333
# Epoch 41/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.3666 - accuracy: 0.8000 - precision: 0.6533 - recall: 0.6533 - f1score: 0.6227 - val_loss: 0.5051 - val_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.6000 - val_f1score: 0.5333
# Epoch 42/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.4599 - accuracy: 0.8133 - precision: 0.6200 - recall: 0.5967 - f1score: 0.5880 - val_loss: 0.4680 - val_accuracy: 0.7333 - val_precision: 0.4667 - val_recall: 0.6000 - val_f1score: 0.5000
# loss: 0.468, accuracy: 0.733, precision: 0.467, recall: 0.600, f1score: 0.500

# %%
print("-- Evaluate --")
scores = model.evaluate_generator(test_generator, steps=5)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# # 6. 모델 사용하기
print("-- Predict --")
output = model.predict_generator(test_generator, steps=5)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)
# Out:
# -- Evaluate --
# accuracy: 73.33%
# -- Predict --
# {'drowning': 0, 'swimming': 1}
# [[0.524]
#  [0.711]
#  [0.841]
#  [0.979]
#  [0.737]
#  [0.984]
#  [0.020]
#  [0.010]
#  [0.352]
#  [0.317]
#  [0.962]
#  [0.380]
#  [0.708]
#  [0.284]
#  [0.796]]

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['val_precision'], 'r', label='val precision')

acc_ax.plot(hist.history['val_recall'], 'g', label='val recall')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('precision')
acc_ax.set_ylabel('recall')

loss_ax.legend(loc='lower right')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['val_f1score'], 'r', label='val precision')



loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('f1score')


loss_ax.legend(loc='lower right')

plt.show()
