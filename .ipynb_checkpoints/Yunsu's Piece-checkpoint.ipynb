# %%
from tensorflow.keras import backend as K
def recall(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Negative) = 실제 값이 1(Positive) 전체
    count_true_positive_false_negative = K.sum(y_target_yn)

    # Recall =  (True Positive) / (True Positive + False Negative)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    recall = count_true_positive / (count_true_positive_false_negative + K.epsilon())

    # return a single tensor value
    return recall


def precision(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Positive) = 예측 값이 1(Positive) 전체
    count_true_positive_false_positive = K.sum(y_pred_yn)

    # Precision = (True Positive) / (True Positive + False Positive)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    precision = count_true_positive / (count_true_positive_false_positive + K.epsilon())

    # return a single tensor value
    return precision


def f1score(y_target, y_pred):
    _recall = recall(y_target, y_pred)
    _precision = precision(y_target, y_pred)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    _f1score = ( 2 * _recall * _precision) / (_recall + _precision+ K.epsilon())
    
    # return a single tensor value
    return _f1score

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping
from matplotlib import pyplot as plt

# %%
# 1. 데이터 생성하기
train_datagen = ImageDataGenerator(rescale=1./255, 
                                   rotation_range=10,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.7,
                                   zoom_range=[0.9, 2.2],
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(
        'data/train',
        target_size=(32, 32),
        batch_size=3,
        class_mode='binary') 

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        'data/test',
        target_size=(32, 32),     
        batch_size=3,
        class_mode='binary')
# Out:
# Found 711 images belonging to 2 classes.
# Found 324 images belonging to 2 classes.

# %%
# 2. 모델 구성하기
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='elu', input_shape=(32,32, 3)))
model.add(Conv2D(32, (3, 3), activation='elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), activation='elu'))
model.add(Conv2D(64, (3, 3), activation='elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(256, activation='elu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid')) 


# 3. 모델 학습과정 설정하기
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001)
#                  ,loss=tf.keras.losses.binary_crossentropy
#                  ,metrics=[tf.keras.metrics.Precision(name='precision')\
#                           ,tf.keras.metrics.Recall(name='recall')\
#                           ,tf.keras.metrics.FalsePositives(name='false_positives')\
#                           ,tf.keras.metrics.FalseNegatives(name='false_negatives')])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', precision, recall, f1score])

early_stopping = EarlyStopping(patience=10) # 조기종료 콜백함수 정의

# 4. 모델 학습시키기
hist = model.fit_generator(
        train_generator,
        steps_per_epoch=50, 
        epochs=500,  
        validation_data=test_generator,
        validation_steps=5,
        callbacks=[early_stopping]) 

_loss, _acc, _precision, _recall, _f1score = model.evaluate_generator(test_generator, steps=5)
print('loss: {:.3f}, accuracy: {:.3f}, precision: {:.3f}, recall: {:.3f}, f1score: {:.3f}'.format(_loss, _acc, _precision, _recall, _f1score))


# # 5. 모델 평가하기
# print("-- Evaluate --")
# scores = model.evaluate_generator(test_generator, steps=5)
# print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# # 6. 모델 사용하기
# print("-- Predict --")
# output = model.predict_generator(test_generator, steps=5)
# np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
# print(test_generator.class_indices)
# print(output)
# Out:
# Epoch 1/500
# 50/50 [==============================] - 2s 37ms/step - loss: 0.8140 - accuracy: 0.5000 - precision: 0.4933 - recall: 0.6433 - f1score: 0.5260 - val_loss: 0.8384 - val_accuracy: 0.7333 - val_precision: 0.7000 - val_recall: 0.9000 - val_f1score: 0.7667
# Epoch 2/500
# 50/50 [==============================] - 2s 34ms/step - loss: 0.8011 - accuracy: 0.5267 - precision: 0.5233 - recall: 0.6267 - f1score: 0.5140 - val_loss: 0.7410 - val_accuracy: 0.5333 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1score: 0.0000e+00
# Epoch 3/500
# 50/50 [==============================] - 2s 34ms/step - loss: 0.7526 - accuracy: 0.5400 - precision: 0.4767 - recall: 0.6467 - f1score: 0.5180 - val_loss: 0.6395 - val_accuracy: 0.6000 - val_precision: 0.5333 - val_recall: 1.0000 - val_f1score: 0.6867
# Epoch 4/500
# 50/50 [==============================] - 2s 36ms/step - loss: 0.6613 - accuracy: 0.6267 - precision: 0.5133 - recall: 0.6633 - f1score: 0.5573 - val_loss: 1.1790 - val_accuracy: 0.3333 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1score: 0.0000e+00
# Epoch 5/500
# 50/50 [==============================] - 2s 34ms/step - loss: 0.7810 - accuracy: 0.5800 - precision: 0.5700 - recall: 0.7467 - f1score: 0.6047 - val_loss: 0.8191 - val_accuracy: 0.5333 - val_precision: 0.5000 - val_recall: 1.0000 - val_f1score: 0.6533
# Epoch 6/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.6301 - accuracy: 0.6133 - precision: 0.5767 - recall: 0.6867 - f1score: 0.5820 - val_loss: 0.6097 - val_accuracy: 0.7333 - val_precision: 0.7333 - val_recall: 1.0000 - val_f1score: 0.8200uracy: 0.6148 - precision: 0.5889 - recall: 0.6963 - f1score: 0.5
# Epoch 7/500
# 50/50 [==============================] - 2s 34ms/step - loss: 0.5626 - accuracy: 0.7400 - precision: 0.7067 - recall: 0.7967 - f1score: 0.7160 - val_loss: 0.7152 - val_accuracy: 0.6000 - val_precision: 0.5333 - val_recall: 1.0000 - val_f1score: 0.6867
# Epoch 8/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.5947 - accuracy: 0.6800 - precision: 0.6767 - recall: 0.7500 - f1score: 0.6700 - val_loss: 0.7180 - val_accuracy: 0.6000 - val_precision: 0.2000 - val_recall: 0.2000 - val_f1score: 0.2000
# Epoch 9/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.5996 - accuracy: 0.7000 - precision: 0.6667 - recall: 0.6700 - f1score: 0.6413 - val_loss: 0.4852 - val_accuracy: 0.6667 - val_precision: 0.5667 - val_recall: 1.0000 - val_f1score: 0.7200: 0.6473 - accuracy: 0.6222 - precision: 0.5556 - recall: 0.6333
# Epoch 10/500
# 50/50 [==============================] - 2s 34ms/step - loss: 0.7652 - accuracy: 0.6467 - precision: 0.5933 - recall: 0.7467 - f1score: 0.6327 - val_loss: 0.6279 - val_accuracy: 0.4667 - val_precision: 0.2000 - val_recall: 0.2000 - val_f1score: 0.2000accuracy: 0.6847 - precision: 0.6126 - recall: 0.7252 - f1score:
# Epoch 11/500
# 50/50 [==============================] - 2s 34ms/step - loss: 0.5856 - accuracy: 0.7067 - precision: 0.6867 - recall: 0.7033 - f1score: 0.6600 - val_loss: 0.5668 - val_accuracy: 0.6667 - val_precision: 0.5667 - val_recall: 1.0000 - val_f1score: 0.7200
# Epoch 12/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.5816 - accuracy: 0.7267 - precision: 0.7000 - recall: 0.7033 - f1score: 0.6587 - val_loss: 0.5703 - val_accuracy: 0.6667 - val_precision: 0.5667 - val_recall: 1.0000 - val_f1score: 0.7200
# Epoch 13/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.5270 - accuracy: 0.7667 - precision: 0.6967 - recall: 0.7033 - f1score: 0.6727 - val_loss: 0.9690 - val_accuracy: 0.6000 - val_precision: 0.6000 - val_recall: 0.6000 - val_f1score: 0.5667
# Epoch 14/500
# 50/50 [==============================] - 2s 34ms/step - loss: 0.8703 - accuracy: 0.5733 - precision: 0.5233 - recall: 0.6500 - f1score: 0.5447 - val_loss: 0.5389 - val_accuracy: 0.6667 - val_precision: 0.4000 - val_recall: 0.4000 - val_f1score: 0.4000
# Epoch 15/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.5317 - accuracy: 0.7400 - precision: 0.7000 - recall: 0.6867 - f1score: 0.6733 - val_loss: 0.5028 - val_accuracy: 0.6667 - val_precision: 0.6000 - val_recall: 0.7000 - val_f1score: 0.6333
# Epoch 16/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.4309 - accuracy: 0.8200 - precision: 0.7667 - recall: 0.7600 - f1score: 0.7420 - val_loss: 0.5614 - val_accuracy: 0.8000 - val_precision: 0.7333 - val_recall: 1.0000 - val_f1score: 0.8267
# Epoch 17/500
# 50/50 [==============================] - 2s 35ms/step - loss: 0.4621 - accuracy: 0.8200 - precision: 0.8300 - recall: 0.8800 - f1score: 0.8220 - val_loss: 0.5092 - val_accuracy: 0.8000 - val_precision: 0.7333 - val_recall: 1.0000 - val_f1score: 0.8267
# Epoch 18/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.4811 - accuracy: 0.8467 - precision: 0.7800 - recall: 0.7867 - f1score: 0.7593 - val_loss: 0.4316 - val_accuracy: 0.8000 - val_precision: 0.7333 - val_recall: 1.0000 - val_f1score: 0.8267
# Epoch 19/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.5022 - accuracy: 0.7867 - precision: 0.7300 - recall: 0.7667 - f1score: 0.7260 - val_loss: 0.3638 - val_accuracy: 0.8000 - val_precision: 0.7333 - val_recall: 1.0000 - val_f1score: 0.8267
# Epoch 20/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.5504 - accuracy: 0.7600 - precision: 0.7933 - recall: 0.8100 - f1score: 0.7707 - val_loss: 0.2453 - val_accuracy: 0.9333 - val_precision: 0.9000 - val_recall: 1.0000 - val_f1score: 0.9333
# Epoch 21/500
# 50/50 [==============================] - 2s 35ms/step - loss: 0.4319 - accuracy: 0.8533 - precision: 0.7800 - recall: 0.8333 - f1score: 0.7913 - val_loss: 0.4427 - val_accuracy: 0.7333 - val_precision: 0.6000 - val_recall: 0.4000 - val_f1score: 0.4667
# Epoch 22/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.3350 - accuracy: 0.8867 - precision: 0.8467 - recall: 0.8633 - f1score: 0.8413 - val_loss: 0.3102 - val_accuracy: 0.8667 - val_precision: 0.8333 - val_recall: 1.0000 - val_f1score: 0.8933
# Epoch 23/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.2488 - accuracy: 0.9067 - precision: 0.8567 - recall: 0.8633 - f1score: 0.8493 - val_loss: 0.5815 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.9000 - val_f1score: 0.8333
# Epoch 24/500
# 50/50 [==============================] - 2s 35ms/step - loss: 0.4434 - accuracy: 0.8267 - precision: 0.7533 - recall: 0.8133 - f1score: 0.7627 - val_loss: 0.4170 - val_accuracy: 0.8000 - val_precision: 0.7333 - val_recall: 1.0000 - val_f1score: 0.8267uracy: 0.8333 - precision: 0.7500 - recall: 0.7955 - f1score: 0.7
# Epoch 25/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.2965 - accuracy: 0.9000 - precision: 0.8167 - recall: 0.8900 - f1score: 0.8407 - val_loss: 0.5691 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.9000 - val_f1score: 0.8333
# Epoch 26/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.3403 - accuracy: 0.8933 - precision: 0.8067 - recall: 0.8567 - f1score: 0.8187 - val_loss: 0.4224 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.9000 - val_f1score: 0.8333
# Epoch 27/500
# 50/50 [==============================] - 2s 35ms/step - loss: 0.3983 - accuracy: 0.8467 - precision: 0.7867 - recall: 0.8567 - f1score: 0.8060 - val_loss: 0.4701 - val_accuracy: 0.8000 - val_precision: 0.7333 - val_recall: 1.0000 - val_f1score: 0.8267
# Epoch 28/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.2600 - accuracy: 0.9200 - precision: 0.8633 - recall: 0.8933 - f1score: 0.8687 - val_loss: 0.3802 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.6000 - val_f1score: 0.6667
# Epoch 29/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.2638 - accuracy: 0.9133 - precision: 0.8033 - recall: 0.8333 - f1score: 0.8053 - val_loss: 0.1549 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1score: 1.0000
# Epoch 30/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.1993 - accuracy: 0.9133 - precision: 0.7967 - recall: 0.8233 - f1score: 0.7980 - val_loss: 0.3504 - val_accuracy: 0.8667 - val_precision: 0.8333 - val_recall: 1.0000 - val_f1score: 0.8933
# Epoch 31/500
# 50/50 [==============================] - 2s 34ms/step - loss: 0.3897 - accuracy: 0.8600 - precision: 0.8000 - recall: 0.8367 - f1score: 0.8007 - val_loss: 0.2565 - val_accuracy: 0.8667 - val_precision: 0.8333 - val_recall: 1.0000 - val_f1score: 0.8933
# Epoch 32/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.4344 - accuracy: 0.8067 - precision: 0.7133 - recall: 0.7767 - f1score: 0.7287 - val_loss: 0.3303 - val_accuracy: 0.8000 - val_precision: 0.7333 - val_recall: 1.0000 - val_f1score: 0.8267
# Epoch 33/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.9757 - accuracy: 0.6800 - precision: 0.6867 - recall: 0.7967 - f1score: 0.6947 - val_loss: 0.3383 - val_accuracy: 0.8667 - val_precision: 0.9000 - val_recall: 0.9000 - val_f1score: 0.8667
# Epoch 34/500
# 50/50 [==============================] - 2s 35ms/step - loss: 0.6415 - accuracy: 0.7200 - precision: 0.7167 - recall: 0.7367 - f1score: 0.7007 - val_loss: 0.4390 - val_accuracy: 0.8000 - val_precision: 0.8333 - val_recall: 0.9000 - val_f1score: 0.8267
# Epoch 35/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.5672 - accuracy: 0.7733 - precision: 0.7433 - recall: 0.8400 - f1score: 0.7600 - val_loss: 0.3847 - val_accuracy: 0.8667 - val_precision: 0.8333 - val_recall: 1.0000 - val_f1score: 0.8933
# Epoch 36/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.3239 - accuracy: 0.8867 - precision: 0.7967 - recall: 0.8400 - f1score: 0.8053 - val_loss: 0.2097 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1score: 1.0000
# Epoch 37/500
# 50/50 [==============================] - 2s 34ms/step - loss: 0.1958 - accuracy: 0.9200 - precision: 0.8400 - recall: 0.8800 - f1score: 0.8480 - val_loss: 0.3430 - val_accuracy: 0.8667 - val_precision: 0.8000 - val_recall: 0.7000 - val_f1score: 0.7333: 0.1905 - accuracy: 0.9195 - precision: 0.8046 - recall: 0.8621 - f1sc
# Epoch 38/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.2909 - accuracy: 0.8867 - precision: 0.8400 - recall: 0.8467 - f1score: 0.8333 - val_loss: 0.2575 - val_accuracy: 0.8667 - val_precision: 0.9000 - val_recall: 0.9000 - val_f1score: 0.9000
# Epoch 39/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.1135 - accuracy: 0.9600 - precision: 0.8567 - recall: 0.8700 - f1score: 0.8587 - val_loss: 0.0620 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1score: 1.0000
# Epoch 40/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.2825 - accuracy: 0.9267 - precision: 0.8367 - recall: 0.8200 - f1score: 0.8187 - val_loss: 0.3499 - val_accuracy: 0.8667 - val_precision: 0.8333 - val_recall: 1.0000 - val_f1score: 0.8933
# Epoch 41/500
# 50/50 [==============================] - 2s 34ms/step - loss: 0.2207 - accuracy: 0.9133 - precision: 0.8700 - recall: 0.9033 - f1score: 0.8707 - val_loss: 0.2263 - val_accuracy: 0.8667 - val_precision: 0.8333 - val_recall: 1.0000 - val_f1score: 0.8933
# Epoch 42/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.2804 - accuracy: 0.8800 - precision: 0.8500 - recall: 0.9100 - f1score: 0.8640 - val_loss: 0.1248 - val_accuracy: 0.9333 - val_precision: 0.9333 - val_recall: 1.0000 - val_f1score: 0.9600
# Epoch 43/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.2485 - accuracy: 0.9133 - precision: 0.7500 - recall: 0.7867 - f1score: 0.7513 - val_loss: 0.1877 - val_accuracy: 0.8667 - val_precision: 0.8333 - val_recall: 1.0000 - val_f1score: 0.8933
# Epoch 44/500
# 50/50 [==============================] - 2s 34ms/step - loss: 0.1567 - accuracy: 0.9333 - precision: 0.8733 - recall: 0.8600 - f1score: 0.8573 - val_loss: 0.1765 - val_accuracy: 0.8667 - val_precision: 0.8333 - val_recall: 1.0000 - val_f1score: 0.8933
# Epoch 45/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.2144 - accuracy: 0.9000 - precision: 0.8333 - recall: 0.8567 - f1score: 0.8273 - val_loss: 0.3727 - val_accuracy: 0.8667 - val_precision: 0.8000 - val_recall: 0.7000 - val_f1score: 0.7333
# Epoch 46/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.3797 - accuracy: 0.8667 - precision: 0.8200 - recall: 0.8233 - f1score: 0.8000 - val_loss: 0.0769 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_f1score: 1.0000
# Epoch 47/500
# 50/50 [==============================] - 2s 34ms/step - loss: 0.2002 - accuracy: 0.9200 - precision: 0.8133 - recall: 0.8600 - f1score: 0.8233 - val_loss: 0.4675 - val_accuracy: 0.8667 - val_precision: 0.8333 - val_recall: 1.0000 - val_f1score: 0.8933
# Epoch 48/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.2776 - accuracy: 0.9133 - precision: 0.8600 - recall: 0.9133 - f1score: 0.8700 - val_loss: 0.2710 - val_accuracy: 0.8667 - val_precision: 0.8333 - val_recall: 1.0000 - val_f1score: 0.8933
# Epoch 49/500
# 50/50 [==============================] - 2s 33ms/step - loss: 0.3232 - accuracy: 0.8600 - precision: 0.7800 - recall: 0.8100 - f1score: 0.7793 - val_loss: 0.1873 - val_accuracy: 0.9333 - val_precision: 0.9333 - val_recall: 1.0000 - val_f1score: 0.9600
# loss: 0.187, accuracy: 0.933, precision: 0.933, recall: 1.000, f1score: 0.960

# %%
print("-- Evaluate --")
scores = model.evaluate_generator(test_generator, steps=5)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# # 6. 모델 사용하기
print("-- Predict --")
output = model.predict_generator(test_generator, steps=5)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)
# Out:
# -- Evaluate --
# accuracy: 93.33%
# -- Predict --
# {'Drowning': 0, 'Swimming': 1}
# [[0.000]
#  [0.001]
#  [0.788]
#  [0.890]
#  [0.463]
#  [0.000]
#  [0.601]
#  [0.692]
#  [0.988]
#  [0.003]
#  [0.964]
#  [0.000]
#  [0.000]
#  [0.919]
#  [0.664]]

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['val_precision'], 'r', label='val precision')

acc_ax.plot(hist.history['val_recall'], 'g', label='val recall')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('precision')
acc_ax.set_ylabel('recall')

loss_ax.legend(loc='lower right')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['val_f1score'], 'r', label='val precision')



loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('f1score')


loss_ax.legend(loc='lower right')

plt.show()
