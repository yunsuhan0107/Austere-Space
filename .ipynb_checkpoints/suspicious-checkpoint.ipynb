# %%
from tensorflow.keras import backend as K
def recall(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Negative) = 실제 값이 1(Positive) 전체
    count_true_positive_false_negative = K.sum(y_target_yn)

    # Recall =  (True Positive) / (True Positive + False Negative)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    recall = count_true_positive / (count_true_positive_false_negative + K.epsilon())

    # return a single tensor value
    return recall


def precision(y_target, y_pred):
    # clip(t, clip_value_min, clip_value_max) : clip_value_min~clip_value_max 이외 가장자리를 깎아 낸다
    # round : 반올림한다
    y_pred_yn = K.round(K.clip(y_pred, 0, 1)) # 예측값을 0(Negative) 또는 1(Positive)로 설정한다
    y_target_yn = K.round(K.clip(y_target, 0, 1)) # 실제값을 0(Negative) 또는 1(Positive)로 설정한다

    # True Positive는 실제 값과 예측 값이 모두 1(Positive)인 경우이다
    count_true_positive = K.sum(y_target_yn * y_pred_yn) 

    # (True Positive + False Positive) = 예측 값이 1(Positive) 전체
    count_true_positive_false_positive = K.sum(y_pred_yn)

    # Precision = (True Positive) / (True Positive + False Positive)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    precision = count_true_positive / (count_true_positive_false_positive + K.epsilon())

    # return a single tensor value
    return precision


def f1score(y_target, y_pred):
    _recall = recall(y_target, y_pred)
    _precision = precision(y_target, y_pred)
    # K.epsilon()는 'divide by zero error' 예방차원에서 작은 수를 더한다
    _f1score = ( 2 * _recall * _precision) / (_recall + _precision+ K.epsilon())
    
    # return a single tensor value
    return _f1score

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping
from matplotlib import pyplot as plt

# %%
# 1. 데이터 생성하기
train_datagen = ImageDataGenerator(rescale=1./255, 
                                   rotation_range=10,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.7,
                                   zoom_range=[0.9, 2.2],
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(
        'data/train',
        target_size=(32, 32),
        batch_size=3,
        class_mode='binary') 

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        'data/test',
        target_size=(32, 32),     
        batch_size=3,
        class_mode='binary')
# Out:
# Found 925 images belonging to 2 classes.
# Found 218 images belonging to 2 classes.

# %%
# 2. 모델 구성하기
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='elu', input_shape=(32,32, 3)))
model.add(Conv2D(32, (3, 3), activation='elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), activation='elu'))
model.add(Conv2D(64, (3, 3), activation='elu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512, activation='elu'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid')) 


# 3. 모델 학습과정 설정하기
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001)
#                  ,loss=tf.keras.losses.binary_crossentropy
#                  ,metrics=[tf.keras.metrics.Precision(name='precision')\
#                           ,tf.keras.metrics.Recall(name='recall')\
#                           ,tf.keras.metrics.FalsePositives(name='false_positives')\
#                           ,tf.keras.metrics.FalseNegatives(name='false_negatives')])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', precision, recall, f1score])

early_stopping = EarlyStopping(patience=10) # 조기종료 콜백함수 정의

# 4. 모델 학습시키기
hist = model.fit_generator(
        train_generator,
        steps_per_epoch=50, 
        epochs=50,  
        validation_data=test_generator,
        validation_steps=5,
        ) 

_loss, _acc, _precision, _recall, _f1score = model.evaluate_generator(test_generator, steps=5)
print('loss: {:.3f}, accuracy: {:.3f}, precision: {:.3f}, recall: {:.3f}, f1score: {:.3f}'.format(_loss, _acc, _precision, _recall, _f1score))


# # 5. 모델 평가하기
# print("-- Evaluate --")
# scores = model.evaluate_generator(test_generator, steps=5)
# print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# # 6. 모델 사용하기
# print("-- Predict --")
# output = model.predict_generator(test_generator, steps=5)
# np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
# print(test_generator.class_indices)
# print(output)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.8393 - accuracy: 0.5000 - precision: 0.2200 - recall: 0.3500 - f1score: 0.2587 - val_loss: 0.7692 - val_accuracy: 0.6000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1score: 0.0000e+00
# Epoch 2/50
# 50/50 [==============================] - 2s 35ms/step - loss: 0.7175 - accuracy: 0.5933 - precision: 0.3133 - recall: 0.3433 - f1score: 0.2973 - val_loss: 0.9873 - val_accuracy: 0.4667 - val_precision: 0.4667 - val_recall: 0.6000 - val_f1score: 0.5200
# Epoch 3/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.7572 - accuracy: 0.5067 - precision: 0.2767 - recall: 0.4033 - f1score: 0.3033 - val_loss: 0.7245 - val_accuracy: 0.5333 - val_precision: 0.4333 - val_recall: 0.5000 - val_f1score: 0.4600
# Epoch 4/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.7364 - accuracy: 0.5000 - precision: 0.3033 - recall: 0.4233 - f1score: 0.3320 - val_loss: 0.9136 - val_accuracy: 0.6667 - val_precision: 0.2000 - val_recall: 0.1000 - val_f1score: 0.1333
# Epoch 5/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.7043 - accuracy: 0.5878 - precision: 0.3367 - recall: 0.4000 - f1score: 0.3380 - val_loss: 0.8295 - val_accuracy: 0.5333 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1score: 0.0000e+00
# Epoch 6/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.6914 - accuracy: 0.5800 - precision: 0.2500 - recall: 0.3133 - f1score: 0.2420 - val_loss: 0.7355 - val_accuracy: 0.5333 - val_precision: 0.4667 - val_recall: 0.6000 - val_f1score: 0.5200
# Epoch 7/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.6236 - accuracy: 0.6067 - precision: 0.2867 - recall: 0.3467 - f1score: 0.2867 - val_loss: 0.6176 - val_accuracy: 0.6000 - val_precision: 0.3000 - val_recall: 0.2000 - val_f1score: 0.2333
# Epoch 8/50
# 50/50 [==============================] - 2s 43ms/step - loss: 0.6477 - accuracy: 0.6216 - precision: 0.3900 - recall: 0.2900 - f1score: 0.3187 - val_loss: 0.7661 - val_accuracy: 0.4667 - val_precision: 0.3000 - val_recall: 0.2000 - val_f1score: 0.2333
# Epoch 9/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.6319 - accuracy: 0.6467 - precision: 0.4200 - recall: 0.3900 - f1score: 0.3833 - val_loss: 0.6646 - val_accuracy: 0.6000 - val_precision: 0.5333 - val_recall: 0.5000 - val_f1score: 0.4933
# Epoch 10/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.5793 - accuracy: 0.7400 - precision: 0.5433 - recall: 0.6333 - f1score: 0.5600 - val_loss: 0.6791 - val_accuracy: 0.5333 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1score: 0.0000e+00
# Epoch 11/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.6283 - accuracy: 0.6333 - precision: 0.4367 - recall: 0.4267 - f1score: 0.4087 - val_loss: 0.5177 - val_accuracy: 0.6667 - val_precision: 0.3000 - val_recall: 0.2000 - val_f1score: 0.2333
# Epoch 12/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.5067 - accuracy: 0.7733 - precision: 0.5100 - recall: 0.5300 - f1score: 0.4960 - val_loss: 0.4598 - val_accuracy: 0.7333 - val_precision: 0.3333 - val_recall: 0.3000 - val_f1score: 0.2933
# Epoch 13/50
# 50/50 [==============================] - 2s 42ms/step - loss: 0.5183 - accuracy: 0.6933 - precision: 0.5333 - recall: 0.5667 - f1score: 0.5187 - val_loss: 0.5320 - val_accuracy: 0.7333 - val_precision: 0.5000 - val_recall: 0.3000 - val_f1score: 0.3667
# Epoch 14/50
# 50/50 [==============================] - 2s 44ms/step - loss: 0.4880 - accuracy: 0.7800 - precision: 0.6167 - recall: 0.5967 - f1score: 0.5800 - val_loss: 0.4659 - val_accuracy: 0.8667 - val_precision: 0.6000 - val_recall: 0.4000 - val_f1score: 0.4667
# Epoch 15/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.4474 - accuracy: 0.8067 - precision: 0.4633 - recall: 0.4333 - f1score: 0.4353 - val_loss: 0.6646 - val_accuracy: 0.7333 - val_precision: 0.4000 - val_recall: 0.2000 - val_f1score: 0.2667
# Epoch 16/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.5376 - accuracy: 0.7333 - precision: 0.4867 - recall: 0.4900 - f1score: 0.4653 - val_loss: 0.4835 - val_accuracy: 0.7333 - val_precision: 0.5000 - val_recall: 0.3000 - val_f1score: 0.3667
# Epoch 17/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.4401 - accuracy: 0.8041 - precision: 0.6700 - recall: 0.6600 - f1score: 0.6473 - val_loss: 0.3607 - val_accuracy: 0.8667 - val_precision: 0.5333 - val_recall: 0.6000 - val_f1score: 0.5600
# Epoch 18/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.4857 - accuracy: 0.8000 - precision: 0.6567 - recall: 0.6933 - f1score: 0.6540 - val_loss: 0.3927 - val_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.4000 - val_f1score: 0.4333
# Epoch 19/50
# 50/50 [==============================] - 2s 42ms/step - loss: 0.4524 - accuracy: 0.7867 - precision: 0.5633 - recall: 0.5767 - f1score: 0.5547 - val_loss: 0.3421 - val_accuracy: 0.8000 - val_precision: 0.5333 - val_recall: 0.4000 - val_f1score: 0.4267
# Epoch 20/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.4770 - accuracy: 0.7533 - precision: 0.6200 - recall: 0.6133 - f1score: 0.5953 - val_loss: 0.3153 - val_accuracy: 0.8667 - val_precision: 0.4667 - val_recall: 0.6000 - val_f1score: 0.5200
# Epoch 21/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.4230 - accuracy: 0.8400 - precision: 0.6867 - recall: 0.6933 - f1score: 0.6680 - val_loss: 0.2807 - val_accuracy: 0.8667 - val_precision: 0.6000 - val_recall: 0.4000 - val_f1score: 0.4667
# Epoch 22/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.4113 - accuracy: 0.8000 - precision: 0.6633 - recall: 0.6133 - f1score: 0.6180 - val_loss: 0.2910 - val_accuracy: 0.8667 - val_precision: 0.6000 - val_recall: 0.4000 - val_f1score: 0.4667
# Epoch 23/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.3467 - accuracy: 0.8600 - precision: 0.6400 - recall: 0.6267 - f1score: 0.6180 - val_loss: 0.1786 - val_accuracy: 0.8667 - val_precision: 0.5333 - val_recall: 0.6000 - val_f1score: 0.5600
# Epoch 24/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.4345 - accuracy: 0.7733 - precision: 0.5733 - recall: 0.5667 - f1score: 0.5507 - val_loss: 0.3335 - val_accuracy: 0.7333 - val_precision: 0.4000 - val_recall: 0.2000 - val_f1score: 0.2667
# Epoch 25/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.4081 - accuracy: 0.8108 - precision: 0.6033 - recall: 0.5800 - f1score: 0.5693 - val_loss: 0.1762 - val_accuracy: 1.0000 - val_precision: 0.6000 - val_recall: 0.6000 - val_f1score: 0.6000
# Epoch 26/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.4700 - accuracy: 0.7800 - precision: 0.7300 - recall: 0.7500 - f1score: 0.7093 - val_loss: 0.3589 - val_accuracy: 0.8000 - val_precision: 0.6000 - val_recall: 0.3000 - val_f1score: 0.4000
# Epoch 27/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.4334 - accuracy: 0.8400 - precision: 0.6200 - recall: 0.6333 - f1score: 0.6193 - val_loss: 0.2073 - val_accuracy: 0.9333 - val_precision: 0.5333 - val_recall: 0.6000 - val_f1score: 0.5600
# Epoch 28/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.3996 - accuracy: 0.8378 - precision: 0.6567 - recall: 0.6233 - f1score: 0.6227 - val_loss: 0.2291 - val_accuracy: 0.9333 - val_precision: 0.5333 - val_recall: 0.6000 - val_f1score: 0.5600
# Epoch 29/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.3585 - accuracy: 0.8133 - precision: 0.6067 - recall: 0.6133 - f1score: 0.5820 - val_loss: 1.1597 - val_accuracy: 0.6667 - val_precision: 0.2000 - val_recall: 0.1000 - val_f1score: 0.1333
# Epoch 30/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.4386 - accuracy: 0.8333 - precision: 0.5500 - recall: 0.5233 - f1score: 0.5220 - val_loss: 0.3373 - val_accuracy: 0.8000 - val_precision: 0.5333 - val_recall: 0.4000 - val_f1score: 0.4267
# Epoch 31/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.3956 - accuracy: 0.8667 - precision: 0.6167 - recall: 0.5867 - f1score: 0.5887 - val_loss: 0.1886 - val_accuracy: 0.8667 - val_precision: 0.6000 - val_recall: 0.4000 - val_f1score: 0.4667
# Epoch 32/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.3051 - accuracy: 0.9200 - precision: 0.6633 - recall: 0.6933 - f1score: 0.6720 - val_loss: 0.2172 - val_accuracy: 0.8000 - val_precision: 0.5000 - val_recall: 0.4000 - val_f1score: 0.4333
# Epoch 33/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.4637 - accuracy: 0.8333 - precision: 0.6633 - recall: 0.6800 - f1score: 0.6487 - val_loss: 0.3553 - val_accuracy: 0.8667 - val_precision: 0.4667 - val_recall: 0.6000 - val_f1score: 0.5200
# Epoch 34/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.4572 - accuracy: 0.8000 - precision: 0.6433 - recall: 0.6667 - f1score: 0.6247 - val_loss: 0.2475 - val_accuracy: 0.9333 - val_precision: 0.5333 - val_recall: 0.6000 - val_f1score: 0.5600
# Epoch 35/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.3830 - accuracy: 0.8446 - precision: 0.6133 - recall: 0.6233 - f1score: 0.5973 - val_loss: 0.2226 - val_accuracy: 0.8667 - val_precision: 0.5333 - val_recall: 0.5000 - val_f1score: 0.4933
# Epoch 36/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.3930 - accuracy: 0.8400 - precision: 0.7300 - recall: 0.7367 - f1score: 0.7140 - val_loss: 0.1562 - val_accuracy: 1.0000 - val_precision: 0.6000 - val_recall: 0.6000 - val_f1score: 0.6000
# Epoch 37/50
# 50/50 [==============================] - 2s 36ms/step - loss: 0.4217 - accuracy: 0.8067 - precision: 0.5100 - recall: 0.5033 - f1score: 0.4927 - val_loss: 0.1450 - val_accuracy: 1.0000 - val_precision: 0.6000 - val_recall: 0.6000 - val_f1score: 0.6000
# Epoch 38/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.3075 - accuracy: 0.9000 - precision: 0.8400 - recall: 0.8567 - f1score: 0.8313 - val_loss: 0.0668 - val_accuracy: 1.0000 - val_precision: 0.6000 - val_recall: 0.6000 - val_f1score: 0.6000
# Epoch 39/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.3519 - accuracy: 0.8467 - precision: 0.6267 - recall: 0.6400 - f1score: 0.6193 - val_loss: 0.1497 - val_accuracy: 0.9333 - val_precision: 0.5333 - val_recall: 0.6000 - val_f1score: 0.5600
# Epoch 40/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.4251 - accuracy: 0.8467 - precision: 0.6267 - recall: 0.6067 - f1score: 0.6000 - val_loss: 1.5185 - val_accuracy: 0.6000 - val_precision: 0.4667 - val_recall: 0.6000 - val_f1score: 0.5200
# Epoch 41/50
# 50/50 [==============================] - 2s 43ms/step - loss: 0.4554 - accuracy: 0.8200 - precision: 0.6233 - recall: 0.6800 - f1score: 0.6300 - val_loss: 0.2209 - val_accuracy: 0.9333 - val_precision: 0.6000 - val_recall: 0.5000 - val_f1score: 0.5333
# Epoch 42/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.3434 - accuracy: 0.8311 - precision: 0.5533 - recall: 0.5367 - f1score: 0.5247 - val_loss: 0.1911 - val_accuracy: 0.8667 - val_precision: 0.6000 - val_recall: 0.4000 - val_f1score: 0.4667
# Epoch 43/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.3258 - accuracy: 0.8533 - precision: 0.6033 - recall: 0.6067 - f1score: 0.5880 - val_loss: 0.2936 - val_accuracy: 0.9333 - val_precision: 0.6000 - val_recall: 0.5000 - val_f1score: 0.5333
# Epoch 44/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.4105 - accuracy: 0.8267 - precision: 0.6800 - recall: 0.6900 - f1score: 0.6593 - val_loss: 0.1378 - val_accuracy: 0.9333 - val_precision: 0.6000 - val_recall: 0.5000 - val_f1score: 0.5333
# Epoch 45/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.3434 - accuracy: 0.8716 - precision: 0.7133 - recall: 0.7000 - f1score: 0.6887 - val_loss: 0.2847 - val_accuracy: 0.8667 - val_precision: 0.5333 - val_recall: 0.6000 - val_f1score: 0.5600
# Epoch 46/50
# 50/50 [==============================] - 2s 39ms/step - loss: 0.4622 - accuracy: 0.8133 - precision: 0.6800 - recall: 0.6933 - f1score: 0.6653 - val_loss: 0.1893 - val_accuracy: 0.9333 - val_precision: 0.6000 - val_recall: 0.5000 - val_f1score: 0.5333
# Epoch 47/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.2878 - accuracy: 0.8933 - precision: 0.5800 - recall: 0.5833 - f1score: 0.5693 - val_loss: 0.1061 - val_accuracy: 1.0000 - val_precision: 0.6000 - val_recall: 0.6000 - val_f1score: 0.6000
# Epoch 48/50
# 50/50 [==============================] - 2s 37ms/step - loss: 0.4077 - accuracy: 0.8267 - precision: 0.5433 - recall: 0.5467 - f1score: 0.5340 - val_loss: 0.5017 - val_accuracy: 0.8000 - val_precision: 0.6000 - val_recall: 0.3000 - val_f1score: 0.4000
# Epoch 49/50
# 50/50 [==============================] - 2s 38ms/step - loss: 0.3861 - accuracy: 0.8400 - precision: 0.6633 - recall: 0.7000 - f1score: 0.6653 - val_loss: 0.2852 - val_accuracy: 0.8667 - val_precision: 0.4667 - val_recall: 0.6000 - val_f1score: 0.5200
# Epoch 50/50
# 50/50 [==============================] - 2s 40ms/step - loss: 0.2883 - accuracy: 0.8733 - precision: 0.7400 - recall: 0.7633 - f1score: 0.7353 - val_loss: 0.1854 - val_accuracy: 0.9333 - val_precision: 0.5333 - val_recall: 0.6000 - val_f1score: 0.5600
# loss: 0.185, accuracy: 0.933, precision: 0.533, recall: 0.600, f1score: 0.560

# %%
print("-- Evaluate --")
scores = model.evaluate_generator(test_generator, steps=5)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# # 6. 모델 사용하기
print("-- Predict --")
output = model.predict_generator(test_generator, steps=5)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)
# Out:
# -- Evaluate --
# accuracy: 93.33%
# -- Predict --
# {'drowning': 0, 'swimming': 1}
# [[0.090]
#  [0.249]
#  [0.073]
#  [1.000]
#  [0.476]
#  [0.961]
#  [0.003]
#  [0.943]
#  [0.994]
#  [0.992]
#  [0.969]
#  [0.767]
#  [0.038]
#  [0.019]
#  [0.016]]

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label='train acc')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val acc')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['val_precision'], 'r', label='val precision')

acc_ax.plot(hist.history['val_recall'], 'g', label='val recall')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('precision')
acc_ax.set_ylabel('recall')

loss_ax.legend(loc='lower right')
acc_ax.legend(loc='lower left')

plt.show()

# %%
fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['val_f1score'], 'r', label='val precision')



loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('f1score')


loss_ax.legend(loc='lower right')

plt.show()
