# %% [markdown]
# # 해야 할 일
#
# - 논문 검색 (google scholar, ieee xplore, dbpia 등)<br/>
#   (관련 키워드 : deep learning, detection, danger ....)
# - 초록 작성 : 찾아본 논문들 참고해서 한글 혹은 영어로 작성
# - 이미지 수집 및 전처리 (32,32,3 이미지 리사이징, 폴더별로 정리)

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 랜덤시드 고정시키기
np.random.seed(3)

# 1. 데이터 생성하기
train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        'data/train',
        target_size=(24, 24), # 우리는 32,32 로 할거니까 변경해줘야겠지 !
        batch_size=3,
        class_mode='binary') #우리는 위험하다 위험하지 않다니까 binary로 변경 
#         class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        'data/test',
        target_size=(24, 24),     # 우리는 32,32 로 할거니까 변경해줘야겠지 !
        batch_size=3,
        class_mode='binary') #우리는 위험하다 위험하지 않다니까 binary로 변경
#         class_mode='categorical')

# 2. 모델 구성하기
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(24,24,3))) # 우리는 32,32 로 할거니까 변경해줘야겠지 !
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid')) 
# 출력 결과는 0혹은1로 해야하니 1으로 변경, softmax는 0부터 1사이의 값으로 바꿔주는거니까 성능이 오히려 떨어질 수 있어서 sigmoid 로 변경
# 참고 URL :  https://m.blog.naver.com/PostView.nhn?blogId=infoefficien&logNo=221170205067&proxyReferer=https%3A%2F%2Fwww.google.com%2F

# 3. 모델 학습과정 설정하기
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 4. 모델 학습시키기
model.fit_generator(
        train_generator,
        steps_per_epoch=10, # 데이터가 30개고, 배치가 3이니까 한 스텝에서 10번 반복한다. 그럼 모든 데이터를 한번씩 다 학습하니까
        epochs=50,  # 전체 학습을 총 50번 한다.
        validation_data=test_generator,
        validation_steps=5)

# 5. 모델 평가하기
print("-- Evaluate --")
scores = model.evaluate_generator(test_generator, steps=5)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# 6. 모델 사용하기
print("-- Predict --")
output = model.predict_generator(test_generator, steps=5)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)
# Out:
# Found 30 images belonging to 2 classes.
# Found 10 images belonging to 2 classes.
# Epoch 1/50
# 10/10 [==============================] - 1s 140ms/step - loss: 0.6455 - accuracy: 0.7667 - val_loss: 0.4044 - val_accuracy: 0.9231
# Epoch 2/50
# 10/10 [==============================] - 0s 31ms/step - loss: 0.0985 - accuracy: 1.0000 - val_loss: 0.1204 - val_accuracy: 1.0000
# Epoch 3/50
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0264 - val_accuracy: 1.0000
# Epoch 4/50
# 10/10 [==============================] - 0s 30ms/step - loss: 2.5197e-04 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 1.0000
# Epoch 5/50
# 10/10 [==============================] - 0s 30ms/step - loss: 2.8591e-05 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 6/50
# 10/10 [==============================] - 0s 31ms/step - loss: 1.4341e-05 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 7/50
# 10/10 [==============================] - 0s 30ms/step - loss: 1.0941e-05 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 8/50
# 10/10 [==============================] - 0s 29ms/step - loss: 8.0240e-06 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 9/50
# 10/10 [==============================] - 0s 30ms/step - loss: 7.4342e-06 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 10/50
# 10/10 [==============================] - 0s 30ms/step - loss: 6.7399e-06 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 11/50
# 10/10 [==============================] - 0s 30ms/step - loss: 6.2830e-06 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 12/50
# 10/10 [==============================] - 0s 30ms/step - loss: 5.8900e-06 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 13/50
# 10/10 [==============================] - 0s 31ms/step - loss: 5.5406e-06 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 1.0000
# Epoch 14/50
# 10/10 [==============================] - 0s 32ms/step - loss: 5.1719e-06 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 15/50
# 10/10 [==============================] - 0s 30ms/step - loss: 5.0102e-06 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 16/50
# 10/10 [==============================] - 0s 31ms/step - loss: 4.7523e-06 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 17/50
# 10/10 [==============================] - 0s 30ms/step - loss: 4.4349e-06 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 18/50
# 10/10 [==============================] - 0s 29ms/step - loss: 4.1816e-06 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 19/50
# 10/10 [==============================] - 0s 30ms/step - loss: 3.9422e-06 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 20/50
# 10/10 [==============================] - 0s 30ms/step - loss: 3.7614e-06 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 21/50
# 10/10 [==============================] - 0s 30ms/step - loss: 3.5830e-06 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 22/50
# 10/10 [==============================] - 0s 30ms/step - loss: 3.3813e-06 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 23/50
# 10/10 [==============================] - 0s 30ms/step - loss: 3.2280e-06 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 24/50
# 10/10 [==============================] - 0s 30ms/step - loss: 3.0995e-06 - accuracy: 1.0000 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 25/50
# 10/10 [==============================] - 0s 30ms/step - loss: 2.9070e-06 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 26/50
# 10/10 [==============================] - 0s 30ms/step - loss: 2.7772e-06 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 27/50
# 10/10 [==============================] - 0s 31ms/step - loss: 2.6597e-06 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 28/50
# 10/10 [==============================] - 0s 30ms/step - loss: 2.5680e-06 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 29/50
# 10/10 [==============================] - 0s 30ms/step - loss: 2.4162e-06 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 30/50
# 10/10 [==============================] - 0s 31ms/step - loss: 2.3155e-06 - accuracy: 1.0000 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 31/50
# 10/10 [==============================] - 0s 31ms/step - loss: 2.2237e-06 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 1.0000
# Epoch 32/50
# 10/10 [==============================] - 0s 30ms/step - loss: 2.1087e-06 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 33/50
# 10/10 [==============================] - 0s 30ms/step - loss: 2.0328e-06 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 34/50
# 10/10 [==============================] - 0s 30ms/step - loss: 1.9449e-06 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 35/50
# 10/10 [==============================] - 0s 29ms/step - loss: 1.8503e-06 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 36/50
# 10/10 [==============================] - 0s 31ms/step - loss: 1.7978e-06 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 37/50
# 10/10 [==============================] - 0s 29ms/step - loss: 1.7306e-06 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 38/50
# 10/10 [==============================] - 0s 30ms/step - loss: 1.6490e-06 - accuracy: 1.0000 - val_loss: 0.0123 - val_accuracy: 1.0000
# Epoch 39/50
# 10/10 [==============================] - 0s 29ms/step - loss: 1.5577e-06 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 40/50
# 10/10 [==============================] - 0s 29ms/step - loss: 1.5138e-06 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 41/50
# 10/10 [==============================] - 0s 29ms/step - loss: 1.4450e-06 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 42/50
# 10/10 [==============================] - 0s 29ms/step - loss: 1.3981e-06 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 43/50
# 10/10 [==============================] - 0s 29ms/step - loss: 1.3349e-06 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 44/50
# 10/10 [==============================] - 0s 29ms/step - loss: 1.3138e-06 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 45/50
# 10/10 [==============================] - 0s 28ms/step - loss: 1.2488e-06 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 46/50
# 10/10 [==============================] - 0s 28ms/step - loss: 1.1971e-06 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 47/50
# 10/10 [==============================] - 0s 29ms/step - loss: 1.1455e-06 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 48/50
# 10/10 [==============================] - 0s 28ms/step - loss: 1.1012e-06 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 49/50
# 10/10 [==============================] - 0s 29ms/step - loss: 1.0697e-06 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 50/50
# 10/10 [==============================] - 0s 29ms/step - loss: 1.0284e-06 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 1.0000
# -- Evaluate --
# accuracy: 100.00%
# -- Predict --
# {'rectangle': 0, 'triangle': 1}
# [[0.000]
#  [1.000]
#  [0.016]
#  [0.000]
#  [1.000]
#  [1.000]
#  [0.000]
#  [0.000]
#  [0.959]
#  [0.995]
#  [0.995]
#  [0.959]
#  [0.000]]
